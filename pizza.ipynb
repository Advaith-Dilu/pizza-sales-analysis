# %%
# =============================
# 🍕 Pizza Sales EDA in Google Colab
# =============================

# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Set plot style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('Set2')

# Step 2: Upload File (you can use the Colab upload dialog)
from google.colab import files
uploaded = files.upload()

# Replace 'pizza_sales.csv' with your actual file name
df = pd.read_csv('pizza_sales.csv')

# Step 3: Basic Info
print("🔍 Basic Dataset Overview")
print(df.shape)
print(df.info())
print(df.head())

# Step 4: Summary Statistics
print("\n📊 Statistical Summary:")
print(df.describe(include='all'))

# Step 5: Check Missing & Duplicates
print("\n🧩 Missing Values:")
print(df.isnull().sum())

print("\n📋 Duplicate Rows:", df.duplicated().sum())

# Step 6: Data Cleaning (example)
# Convert date columns to datetime if present
date_cols = ['order_date', 'date', 'Order Date']
for col in date_cols:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col])

# Step 7: Create useful columns if missing
if 'total_price' not in df.columns and {'quantity', 'price'}.issubset(df.columns):
    df['total_price'] = df['quantity'] * df['price']

# Step 8: Exploratory Data Analysis (Basic Insights)
print("\n🍕 Top 5 Pizza Types by Sales:")
if 'pizza_name' in df.columns:
    print(df.groupby('pizza_name')['total_price'].sum().sort_values(ascending=False).head(5))

print("\n📦 Orders per Pizza Category:")
if 'pizza_category' in df.columns:
    print(df['pizza_category'].value_counts())

# Step 9: Visualization — Sales Overview
plt.figure(figsize=(8,5))
sns.histplot(df['total_price'], bins=30, kde=True)
plt.title('Distribution of Total Price')
plt.xlabel('Total Price')
plt.ylabel('Frequency')
plt.show()

# Step 10: Category-Wise Sales
if 'pizza_category' in df.columns:
    plt.figure(figsize=(8,5))
    category_sales = df.groupby('pizza_category')['total_price'].sum().sort_values(ascending=False)
    sns.barplot(x=category_sales.index, y=category_sales.values)
    plt.title('Total Sales by Pizza Category')
    plt.xlabel('Category')
    plt.ylabel('Total Sales ($)')
    plt.show()

# Step 11: Top 10 Best-Selling Pizzas
if 'pizza_name' in df.columns:
    top_pizzas = df.groupby('pizza_name')['total_price'].sum().sort_values(ascending=False).head(10)
    plt.figure(figsize=(10,6))
    sns.barplot(x=top_pizzas.values, y=top_pizzas.index)
    plt.title('Top 10 Best-Selling Pizzas')
    plt.xlabel('Total Sales ($)')
    plt.ylabel('Pizza Name')
    plt.show()

# Step 12: Sales Trend Over Time
if any(col in df.columns for col in date_cols):
    time_col = [col for col in date_cols if col in df.columns][0]
    daily_sales = df.groupby(df[time_col].dt.date)['total_price'].sum()
    plt.figure(figsize=(10,5))
    daily_sales.plot()
    plt.title('Daily Sales Trend')
    plt.xlabel('Date')
    plt.ylabel('Total Sales ($)')
    plt.show()

# Step 13: Correlation Analysis
numeric_cols = df.select_dtypes(include=[np.number])
plt.figure(figsize=(8,5))
sns.heatmap(numeric_cols.corr(), annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()

# Step 14: Hourly/Day Analysis (if time available)
if 'order_time' in df.columns:
    df['order_hour'] = pd.to_datetime(df['order_time']).dt.hour
    plt.figure(figsize=(8,4))
    sns.countplot(x='order_hour', data=df)
    plt.title('Orders by Hour of the Day')
    plt.show()

print("\n✅ EDA Completed Successfully!")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-3306620941.py in <cell line: 0>()
#      16 # Step 2: Upload File (you can use the Colab upload dialog)
#      17 from google.colab import files
# ---> 18 uploaded = files.upload()
#      19
#      20 # Replace 'pizza_sales.csv' with your actual file name
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in upload(target_dir)
#      70   """
#      71
# ---> 72   uploaded_files = _upload_files(multiple=True)
#      73   # Mapping from original filename to filename as saved locally.
#      74   local_filenames = dict()
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in _upload_files(multiple)
#     170
#     171   while result['action'] != 'complete':
# --> 172     result = _output.eval_js(
#     173         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# ...

# %%
# =============================
# 🍕 Pizza Sales EDA in Google Colab
# =============================

# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Set plot style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('Set2')

# Step 2: Upload File (you can use the Colab upload dialog)
from google.colab import files
uploaded = files.upload()

# Replace 'pizza_sales.csv' with your actual file name
df = pd.read_csv('pizza_sales.csv')

# Step 3: Basic Info
print("🔍 Basic Dataset Overview")
print(df.shape)
print(df.info())
print(df.head())

# Step 4: Summary Statistics
print("\n📊 Statistical Summary:")
print(df.describe(include='all'))

# Step 5: Check Missing & Duplicates
print("\n🧩 Missing Values:")
print(df.isnull().sum())

print("\n📋 Duplicate Rows:", df.duplicated().sum())

# Step 6: Data Cleaning (example)
# Convert date columns to datetime if present
date_cols = ['order_date', 'date', 'Order Date']
for col in date_cols:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col])

# Step 7: Create useful columns if missing
if 'total_price' not in df.columns and {'quantity', 'price'}.issubset(df.columns):
    df['total_price'] = df['quantity'] * df['price']

# Step 8: Exploratory Data Analysis (Basic Insights)
print("\n🍕 Top 5 Pizza Types by Sales:")
if 'pizza_name' in df.columns:
    print(df.groupby('pizza_name')['total_price'].sum().sort_values(ascending=False).head(5))

print("\n📦 Orders per Pizza Category:")
if 'pizza_category' in df.columns:
    print(df['pizza_category'].value_counts())

# Step 9: Visualization — Sales Overview
plt.figure(figsize=(8,5))
sns.histplot(df['total_price'], bins=30, kde=True)
plt.title('Distribution of Total Price')
plt.xlabel('Total Price')
plt.ylabel('Frequency')
plt.show()

# Step 10: Category-Wise Sales
if 'pizza_category' in df.columns:
    plt.figure(figsize=(8,5))
    category_sales = df.groupby('pizza_category')['total_price'].sum().sort_values(ascending=False)
    sns.barplot(x=category_sales.index, y=category_sales.values)
    plt.title('Total Sales by Pizza Category')
    plt.xlabel('Category')
    plt.ylabel('Total Sales ($)')
    plt.show()

# Step 11: Top 10 Best-Selling Pizzas
if 'pizza_name' in df.columns:
    top_pizzas = df.groupby('pizza_name')['total_price'].sum().sort_values(ascending=False).head(10)
    plt.figure(figsize=(10,6))
    sns.barplot(x=top_pizzas.values, y=top_pizzas.index)
    plt.title('Top 10 Best-Selling Pizzas')
    plt.xlabel('Total Sales ($)')
    plt.ylabel('Pizza Name')
    plt.show()

# Step 12: Sales Trend Over Time
if any(col in df.columns for col in date_cols):
    time_col = [col for col in date_cols if col in df.columns][0]
    daily_sales = df.groupby(df[time_col].dt.date)['total_price'].sum()
    plt.figure(figsize=(10,5))
    daily_sales.plot()
    plt.title('Daily Sales Trend')
    plt.xlabel('Date')
    plt.ylabel('Total Sales ($)')
    plt.show()

# Step 13: Correlation Analysis
numeric_cols = df.select_dtypes(include=[np.number])
plt.figure(figsize=(8,5))
sns.heatmap(numeric_cols.corr(), annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()

# Step 14: Hourly/Day Analysis (if time available)
if 'order_time' in df.columns:
    df['order_hour'] = pd.to_datetime(df['order_time']).dt.hour
    plt.figure(figsize=(8,4))
    sns.countplot(x='order_hour', data=df)
    plt.title('Orders by Hour of the Day')
    plt.show()

print("\n✅ EDA Completed Successfully!")
# Out:
#      <input type="file" id="files-fde274f9-a738-4529-a2b2-72b7cf9c7ad9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fde274f9-a738-4529-a2b2-72b7cf9c7ad9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# The uploaded file name was 'Data Model - Pizza Sales.xlsx'
# Use pd.read_excel to read the Excel file
df = pd.read_excel('Data Model - Pizza Sales.xlsx')

# Display the first few rows to confirm it's loaded correctly
print("🔍 Basic Dataset Overview")
print(df.shape)
print(df.info())
display(df.head())
# Out:
# 🔍 Basic Dataset Overview
# (48620, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_id           48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 4.5+ MB
# None
# ...

# %%
print("\n📊 Statistical Summary:")
print(df.describe(include='all'))
# Out:
# 📊 Statistical Summary:
#         order_details_id      order_id    pizza_id      quantity  \
# count       48620.000000  48620.000000       48620  48620.000000
# unique               NaN           NaN          91           NaN
# top                  NaN           NaN  big_meat_s           NaN
# freq                 NaN           NaN        1811           NaN
# mean        24310.500000  10701.479761         NaN      1.019622
# min             1.000000      1.000000         NaN      1.000000
# 25%         12155.750000   5337.000000         NaN      1.000000
# 50%         24310.500000  10682.500000         NaN      1.000000
# 75%         36465.250000  16100.000000         NaN      1.000000
# max         48620.000000  21350.000000         NaN      4.000000
# std         14035.529381   6180.119770         NaN      0.143077
#
#                            order_date order_time    unit_price   total_price  \
# count                           48620      48620  48620.000000  48620.000000
# ...

# %%
print("\n🧩 Missing Values:")
print(df.isnull().sum())
# Out:
# 🧩 Missing Values:
# order_details_id     0
# order_id             0
# pizza_id             0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
date_cols = ['order_date', 'date', 'Order Date']
for col in date_cols:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col])

# %%
if 'total_price' not in df.columns and {'quantity', 'price'}.issubset(df.columns):
    df['total_price'] = df['quantity'] * df['price']

# %%
if 'pizza_category' in df.columns:
    plt.figure(figsize=(8,5))
    category_sales = df.groupby('pizza_category')['total_price'].sum().sort_values(ascending=False)
    sns.barplot(x=category_sales.index, y=category_sales.values)
    plt.title('Total Sales by Pizza Category')
    plt.xlabel('Category')
    plt.ylabel('Total Sales ($)')
    plt.show()

# Step 11: Top 10 Best-Selling Pizzas
if 'pizza_name' in df.columns:
    top_pizzas = df.groupby('pizza_name')['total_price'].sum().sort_values(ascending=False).head(10)
    plt.figure(figsize=(10,6))
    sns.barplot(x=top_pizzas.values, y=top_pizzas.index)
    plt.title('Top 10 Best-Selling Pizzas')
    plt.xlabel('Total Sales ($)')
    plt.ylabel('Pizza Name')
    plt.show()

# Step 12: Sales Trend Over Time
if any(col in df.columns for col in date_cols):
    time_col = [col for col in date_cols if col in df.columns][0]
    daily_sales = df.groupby(df[time_col].dt.date)['total_price'].sum()
    plt.figure(figsize=(10,5))
    daily_sales.plot()
    plt.title('Daily Sales Trend')
    plt.xlabel('Date')
    plt.ylabel('Total Sales ($)')
    plt.show()

# Step 13: Correlation Analysis
numeric_cols = df.select_dtypes(include=[np.number])
plt.figure(figsize=(8,5))
sns.heatmap(numeric_cols.corr(), annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()

# Step 14: Hourly/Day Analysis (if time available)
if 'order_time' in df.columns and 'order_date' in df.columns:
    # Convert 'order_time' to string and combine with 'order_date' for full datetime conversion
    df['order_datetime'] = pd.to_datetime(df['order_date'].astype(str) + ' ' + df['order_time'].astype(str))
    df['order_hour'] = df['order_datetime'].dt.hour
    plt.figure(figsize=(8,4))
    sns.countplot(x='order_hour', data=df)
    plt.title('Orders by Hour of the Day')
    plt.xlabel('Hour of the Day')
    plt.ylabel('Number of Orders')
    plt.show()

print("\n✅ EDA Completed Successfully!")
# Out:
# ✅ EDA Completed Successfully!
